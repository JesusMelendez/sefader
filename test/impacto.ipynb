# %%
import pandas as pd
import numpy as np

# %%
path = '../data/impacto_dataset.csv'

# %%
resultados = pd.read_csv(path)

# %%
resultados.columns
# Out:
# Index(['Bitácora registrada por', 'NomUsuario', 'ID_Bitacora',
#        'Tipo de bitácora', 'Año-ciclo-bitácora', 'Régimen hídrico',
#        'Id_Cultivos', 'Tipo de superficie', 'Cultivo 1', 'Cultivo 2',
#        'Cultivo 3', 'Superficie sembrada (ha)', '02_Costo semilla',
#        '04_Análisis de suelo', '05_Análisis de agua', '06_Nivelación',
#        '07_Curvas de nivel', '08_Conservación de suelo y agua',
#        '09_Aplicación de insumos', '10_Preparación mecánica del suelo',
#        '11_Siembra', '12_Control  físico de malezas', '13_Riego',
#        '¿Obtuvo cosecha?', '14_Cosecha manual', '14_Cosecha motorizada',
#        '16_Costos comercialización', '18_Gastos indirectos',
#        '19_Labores culturales', 'Costo acumulado', 'Ingresos_totales',
#        'ID_Productividad', 'C1P1-¿Cuántos productos cosecho del cultivo 1?',
#        'Tipo de semilla C1', 'C1P2-Producto obtenido',
#        'C1P2-Rendimiento real (Unidad/ha)', 'C1P2-Unidad de medida'],
# ...

# %%
resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2562 entries, 0 to 2561
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Bitácora registrada por                         2562 non-null   object
#  1   NomUsuario                                      2562 non-null   object
#  2   ID_Bitacora                                     2562 non-null   object
#  3   Tipo de bitácora                                2562 non-null   object
#  4   Año-ciclo-bitácora                              2560 non-null   object
#  5   Régimen hídrico                                 2562 non-null   object
#  6   Id_Cultivos                                     2509 non-null   object
#  7   Tipo de superficie                              2508 non-null   object
#  8   Cultivo 1                                       2508 non-null   object
# ...

# %%
label_inn={
    'AE':'Innovacion',
    'AI':'Innovacion'
}

# %%
resultados['Tipo de superficie'] = resultados['Tipo de superficie'].fillna(resultados['Tipo de bitácora'].map(label_inn))

# %%
resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2562 entries, 0 to 2561
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Bitácora registrada por                         2562 non-null   object
#  1   NomUsuario                                      2562 non-null   object
#  2   ID_Bitacora                                     2562 non-null   object
#  3   Tipo de bitácora                                2562 non-null   object
#  4   Año-ciclo-bitácora                              2560 non-null   object
#  5   Régimen hídrico                                 2562 non-null   object
#  6   Id_Cultivos                                     2509 non-null   object
#  7   Tipo de superficie                              2542 non-null   object
#  8   Cultivo 1                                       2508 non-null   object
# ...

# %%
resultados['pk'] = resultados['ID_Bitacora'] + '_' + resultados['Tipo de bitácora']+'_' + resultados['Tipo de superficie']

# %%
resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2562 entries, 0 to 2561
# Data columns (total 38 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Bitácora registrada por                         2562 non-null   object
#  1   NomUsuario                                      2562 non-null   object
#  2   ID_Bitacora                                     2562 non-null   object
#  3   Tipo de bitácora                                2562 non-null   object
#  4   Año-ciclo-bitácora                              2560 non-null   object
#  5   Régimen hídrico                                 2562 non-null   object
#  6   Id_Cultivos                                     2509 non-null   object
#  7   Tipo de superficie                              2542 non-null   object
#  8   Cultivo 1                                       2508 non-null   object
# ...

# %%
resultados[resultados['pk'].isnull()]
# Out:
#                  Bitácora registrada por              NomUsuario  \
# 174             EMMANUEL LORENZO PASCUAL    EMMANUELLORENZO_PSUR
# 176                 ABIGAIL REYES ARANDA       ABIGAILREYES_PSUR
# 177                 ABIGAIL REYES ARANDA       ABIGAILREYES_PSUR
# 180   MARIAM DE LOS CIELOS RUIZ GREGORIO         MARIAMRUIZ_PSUR
# 181          ELDA LUCIA SANTIAGO PACHECO       ELDASANTIAGO_PSUR
# 855             CARLOS SANTIAGO BAUTISTA     CARLOSSANTIAGO_PSUR
# 1314          JUAN EMILIO BENITEZ CANTON        JUANBENITEZ_PSUR
# 1502         RUBICELIA MARTÍNEZ MARTÍNEZ  RUBICELIAMARTINEZ_PSUR
# 1538            JONATHAN VILLA ALCANTARA      JONATHANVILLA_PSUR
# 1631                 ARLET LÓPEZ JIMÉNEZ         ARLETLOPEZ_PSUR
# 1632                 ARLET LÓPEZ JIMÉNEZ         ARLETLOPEZ_PSUR
# 1788             PATRICIA JUAREZ RAMIREZ     PATRICIAJUAREZ_PSUR
# 1884     CELSA MARIELA RODRÍGUEZ ARTEAGA     CELSARODRIGUEZ_PSUR
# ...

# %%
resultados['Cultivo 1'].value_counts()
# Out:
# Cultivo 1
# MAIZ          2459
# FRIJOL          39
# CALABACITA       4
# HABA             3
# JAMAICA          1
# CHILE            1
# OTRO             1
# Name: count, dtype: int64

# %%
resultados.groupby('Cultivo 1')['Costo acumulado'].agg('mean').plot(kind='bar')
# Out:
# <Axes: xlabel='Cultivo 1'>
