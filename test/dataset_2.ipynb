# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import re
from shapely.geometry import Point, Polygon

# %% [markdown]
# corte oct

# %%
corte_oc = pd.read_csv('../data/Bit_TecnologiasGenerales_OCT.csv')
# Out:
# /tmp/ipykernel_5154/2442079992.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   corte_oc = pd.read_csv('../data/Bit_TecnologiasGenerales_OCT.csv')

# %%
corte_oc.shape
# (42873, 79) sept
# Out:
# (42874, 34)

# %%
corte_oc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42874 entries, 0 to 42873
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID.de.bitacora                  42874 non-null  object
#  1   Tipo.de.superficie              42874 non-null  object
#  2   ID.del.productor                4144 non-null   object
#  3   Nombre.Productor                42874 non-null  object
#  4   CURP                            4144 non-null   object
#  5   ID.parcela                      1950 non-null   object
#  6   ID.del.sitio                    3470 non-null   object
#  7   Nombre.de.la.Parcela            42874 non-null  object
#  8   Estado.areas                    42874 non-null  object
#  9   Municipio.areas                 42872 non-null  object
#  10  Coordenadas.areas               42874 non-null  object
#  11  Tipo.de.bitacora                42874 non-null  object
#  12  Anio.Bitacora                   42869 non-null  object
#  13  Ciclo                           42874 non-null  object
#  14  Regimen.hidrico                 42874 non-null  object
#  15  Superficie.sembrada             42874 non-null  float64
#  16  Superficie.Total.de.la.parcela  42874 non-null  float64
#  17  Cultivo.1                       42874 non-null  object
#  18  Cultivo.2                       15439 non-null  object
#  19  Cultivo.3                       12142 non-null  object
#  20  Proyecto                        42874 non-null  object
#  21  Bitacora.registrada.por         42874 non-null  object
#  22  Id_Cultivos                     42874 non-null  object
#  23  1_Agricultura de conservacion   42874 non-null  int64
#  24  2_Arreglos de siembra           42874 non-null  int64
#  25  3_Comercializacion              42874 non-null  int64
#  26  4_Conservacion de agua          42874 non-null  int64
#  27  5_Conservacion del suelo        42874 non-null  int64
#  28  6_Fertilizacion                 42874 non-null  int64
#  29  7_Manejo integrado de plagas    42874 non-null  int64
#  30  8_Tecnologias de poscosecha     42874 non-null  int64
#  31  9_Variedades mejoradas          42874 non-null  int64
#  32  10_Otra                         42874 non-null  int64
#  33  SumTecs                         42874 non-null  int64
# dtypes: float64(2), int64(11), object(21)
# memory usage: 11.1+ MB

# %%
corte_oc['ID.de.bitacora'].nunique()
# 42485
# Out:
# 42485

# %%
corte_oc['Tipo.de.superficie'].isnull().sum()
# Out:
# 0

# %%
corte_oc['primary_k'] = corte_oc['ID.de.bitacora']+'_'+corte_oc['Tipo.de.bitacora']+'_'+corte_oc['Tipo.de.superficie']

# %%
corte_oc['primary_k'].nunique()
#42873 sept
# Out:
# 42874

# %%
#union de nombre tecnioc para determinar programa
programa = pd.read_csv('../data/relacion_tecnicos_programa_eagrology.csv')

# %%
programa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               241 non-null    int64
#  1   Bitacora.registrada.por  241 non-null    object
#  2   NOMBRE DEL USUARIO       196 non-null    object
#  3   Nombre del técnico       144 non-null    object
#  4   Programa                 144 non-null    object
#  5   Región de atención       144 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 11.4+ KB

# %%
programa['Bitacora.registrada.por'].nunique()
#241 sept
# Out:
# 241

# %%
octubre_corte=corte_oc.merge(programa[['Bitacora.registrada.por','Programa']],on='Bitacora.registrada.por',how='left')

# %%
octubre_corte.shape
# Out:
# (42874, 36)

# %%
octubre_corte.Programa.unique()
# Out:
# array([nan, 'Abasto Seguro de Maíz', 'Autosuficiencia Alimentaria'],
#       dtype=object)

# %%
octubre_corte.Programa.fillna('Sin Identificar',inplace=True)
# Out:
# /tmp/ipykernel_5154/1678271815.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   octubre_corte.Programa.fillna('Sin Identificar',inplace=True)

# %%
octubre_corte.Programa.unique()
# Out:
# array(['Sin Identificar', 'Abasto Seguro de Maíz',
#        'Autosuficiencia Alimentaria'], dtype=object)

# %%
octubre_corte['Anio.Bitacora'].unique()
# Out:
# array(['PV_2023', 'OI_2023_2024', 'OI_2022_2023', 'PV_2024', 'PV_2022',
#        nan, 'PV_2019', 'PV_2020', 'PV_2021', 'OI_2021_2022',
#        'OI_2018_2019', 'OI_2024_2025', 'PV_2025'], dtype=object)

# %%
octubre_corte['Anio.Bitacora'].fillna('Vacío',inplace=True)
# Out:
# /tmp/ipykernel_5154/4275594233.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   octubre_corte['Anio.Bitacora'].fillna('Vacío',inplace=True)

# %%
octubre_corte['Anio.Bitacora'].unique()
# Out:
# array(['PV_2023', 'OI_2023_2024', 'OI_2022_2023', 'PV_2024', 'PV_2022',
#        'Vacío', 'PV_2019', 'PV_2020', 'PV_2021', 'OI_2021_2022',
#        'OI_2018_2019', 'OI_2024_2025', 'PV_2025'], dtype=object)

# %%
def replace_chracter(x):
    text = re.sub('_',' ',x)
    return text

# %%
octubre_corte['Anio.Bitacora'] = octubre_corte['Anio.Bitacora'].apply(replace_chracter)

# %%
octubre_corte['Anio.Bitacora'].unique()
# Out:
# array(['PV 2023', 'OI 2023 2024', 'OI 2022 2023', 'PV 2024', 'PV 2022',
#        'Vacío', 'PV 2019', 'PV 2020', 'PV 2021', 'OI 2021 2022',
#        'OI 2018 2019', 'OI 2024 2025', 'PV 2025'], dtype=object)

# %%
# %%timeit
def to_float(i):
    """
    el parámetro i es un del tipo str
    -----------------------------------
    La función to_float convierte a 'i' a tipo flotante
    -----------------------------------
    devuelve un valor del tipo float
    
    """
    try:
        i = re.sub(r"\\t",'',i)
        i = float(i)
        return i 
    except:
        pass
    return i

# %%
# %%timeit
def transform(row):
    """
    el parámetro row es un valor del tipo str
    ----------------------------------------------
    separa los elementos de cada row de acuerdo a ciertos caracteres
    depura aquellos que no cumplen ciertas condiciones asignandoles el valor de lista vacia
    transforma cada cadena de texto a valores del tipo float
    ------------------------------------------------
    Retorna coor la cual puede ser una lista con valores flotantes 
    o una lista vacía.

    """
    input = row.split(',')

    size_list = len(input)


    if size_list ==1:
        coor = None

    elif size_list ==2:
        try:
            # input.replace('\\t','')
            pre_punto = map(to_float,input)
            coor = list(pre_punto)
            if None in coor:
                coor = None
                return coor
            elif '°' in coor:
                corr = None
                return corr 
            else:
                return coor
        except ValueError as e:
            print(e)
            return None
    elif size_list >2:
        not_point = re.split(r",0\\n\\n|,0|0\s-|,",row)
        if ("" in not_point):
            not_point.remove("")
            list_with_float = map(to_float,not_point)
            coor = list(list_with_float)
            return coor
        else:
            list_with_float = map(to_float,not_point)
            coor = list(list_with_float)
            return coor

# %%
# %%timeit
def to_matrix(listado):
    """
    el parámetro listado es un objeto del tipo lista
    -----------------------------------
    transforma una lista a un array de numpy
    asigna la forma del array
    -----------------------------------
    devuelve una matriz
    """
    n = len(listado)
    c = 2
    f =  n/c
    f = int(f)
    vector = np.array(listado)
    matriz = vector.reshape(f,c)
    return matriz

# %%
# %%timeit
def geometry_apply(x):
    """
    el parámetro x es una lista
    ------------------------------------------
    de acuerdo a la longitud de la lista aplica una o dos funciones
    -----------------------------------------
    devuelve geometry que puede ser un objeto Point, Polygon o un valor None
    """

    n = x
    if len(n) == 2:
        # orden=arreglo(n)
        # p=sorted(n)
        # print(p)
        geometry = Point(n)
    elif len(n) >5 and len(n) %2 == 0: #Nueva validación
        listado = to_matrix(n)
        geometry = Polygon(listado)
    else:
        geometry = None
    print(geometry)
    return geometry

# %%
# %%timeit
def typeshape(x):
    """
    El parámetro x es un str
    ----------------------------------------
    De acuerdo al valor genera ciertas cadenas de texto
    ---------------------------------------
    retorna label que es un str
    """
    n=x
    if int(n) == 2:
        label = "Point"
    else:
        label = "Polygon"
    return label

# %%
# %%timeit
def to_geopandas_df(df,origin_file):
    """
    file_input recibe al archivo Sitios.txt
    -----------------------------------------------
    Lee el archivo
    genera columnas y aplica funciones
    crea 3 subsets distintos
    elimina columnas temporales y columna Coordenadas areas
    exportar los sets a un formato específico
    -----------------------------------------------
    genera los archivos de salida o un error
    """
    try:
        
         #read   
        # sitios= pd.read_csv(file_input)
        sitiosbd = df.copy()
        #crear col geografica
        sitiosbd['info_geo'] = sitiosbd['Coordenadas.areas']
        #castear dato a str
        sitiosbd['info_geo']=sitiosbd['info_geo'].astype(str)
        #se aplica transform
        sitiosbd['info_geo']= sitiosbd['info_geo'].apply(transform)
        desechados=sitiosbd[sitiosbd['info_geo'].isnull()]
        sitiosbd_depurate=sitiosbd[sitiosbd['info_geo'].notna()]
        sitiosbd_depurate['n_vertices'] = sitiosbd_depurate['info_geo'].apply(lambda x:len(x))
        # sitiosbd_depurate.to_csv(f'{PATH}n_vertices.csv')
        # sitiosbd_depurate['type_geometry'] = sitiosbd_depurate['info_geo'].apply(arreglo)
        sitiosbd_depurate['type_geometry'] = sitiosbd_depurate['info_geo'].apply(geometry_apply)
        sitiosbd_depurate=sitiosbd_depurate[sitiosbd_depurate['type_geometry'].notna()]
        desechados_2=sitiosbd_depurate[sitiosbd_depurate['type_geometry'].isnull()]
        desechados = pd.concat([desechados_2,desechados],axis=0)
        desechados.to_csv(f'./errors_{origin_file}.csv', index=False)
        sitiosbd_depurate['type_shape'] = sitiosbd_depurate['n_vertices'].apply(typeshape)
        sitiosbd_polygon = sitiosbd_depurate[sitiosbd_depurate['type_shape']=='Polygon']
        sitiosbd_point = sitiosbd_depurate[sitiosbd_depurate['type_shape']=='Point']
        
        gdf_points_sitios = gpd.GeoDataFrame(sitiosbd_point,geometry='type_geometry',crs="EPSG:4326")
        gdf_polygons_sitios = gpd.GeoDataFrame(sitiosbd_polygon,geometry='type_geometry',crs="EPSG:4326")
 #el formato GeoJSON no soporta el formato de listas(un arreglo)
        # geopandas_df  = gpd.GeoDataFrame(sitiosbd_depurate,geometry='type_geometry',crs="EPSG:4326")
        # eliminar = ['Coordenadas.areas','info_geo','n_vertices','Nombre.Productor','Bitacora.registrada.por']
        # eliminar = ['Coordenadas.areas','info_geo','n_vertices','type_shape','Nombre.Productor','Bitacora.registrada.por']
        eliminar = ['Coordenadas.areas','info_geo','n_vertices','type_shape','Bitacora.registrada.por','Nombre.Productor']
        # geopandas_df=geopandas_df.drop(columns=eliminar)
        gdf_points_sitios=gdf_points_sitios.drop(columns=eliminar)
        gdf_polygons_sitios=gdf_polygons_sitios.drop(columns=eliminar)
        return gdf_points_sitios,gdf_polygons_sitios
        # gdf_points_sitios.to_file(puntos,driver='GeoJSON')
        # gdf_polygons_sitios.to_file(poligonos,driver='GeoJSON')
    except FileNotFoundError as e:
        print(f'Por favor ejecute el script en el mismo directorio donde se encuentre el archivo Sitio.txt {e}')

# %% [markdown]
# Transf to geo

# %%
pts, pols=to_geopandas_df(octubre_corte,'oct_30_')
# Out:
# /tmp/ipykernel_5154/923546810.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sitiosbd_depurate['n_vertices'] = sitiosbd_depurate['info_geo'].apply(lambda x:len(x))
# POLYGON ((-95.89601519 17.75389612, -95.89536609 17.75461648, -95.89739921 17.75523465, -95.89780154 17.75434059, -95.89601519 17.75389612))
# POLYGON ((-95.51424973 16.4406485, -95.51435165 16.44067422, -95.51416926 16.44113214, -95.51419072 16.44124018, -95.5143141 16.4413225, -95.5144643 16.44130707, -95.51460378 16.44123504, -95.5144804 16.44155403, -95.5143141 16.44169809, -95.51417462 16.4417444, -95.51405124 16.44174954, -95.51396541 16.44171867, -95.5139064 16.44167237, -95.51386885 16.44161063, -95.51374011 16.4416878, -95.51377229 16.44201194, -95.51360063 16.44251616, -95.51324121 16.44245956, -95.5132734 16.44200165, -95.51322512 16.44187817, -95.51321439 16.44175983, -95.51325731 16.44161063, -95.51333777 16.44145628, -95.51348261 16.44132765, -95.51367037 16.4411733, -95.51385812 16.44106011, -95.51401369 16.44096749, -95.51417999 16.44063821, -95.51424973 16.4406485))
# POLYGON ((-95.52305923 16.44835046, -95.52331136 16.44731633, -95.52385317 16.44749126, -95.52348302 16.44842763, -95.52020536 16.44806234, -95.51984594 16.44856654, -95.52004979 16.44862314, -95.52026973 16.44864886, -95.52050577 16.44863857, -95.52139626 16.44840705, -95.52143381 16.44820126, -95.5218576 16.4482527, -95.52305923 16.44835046))
# POINT (16.049681 -95.668625)
# POINT (16.517881 -96.96936)
# POINT (15.949788 -95.727008)
# POINT (16.653224 -94.195702)
# POINT (18.191527 -96.94082)
# POINT (16.92006 -96.57736)
# POINT (16.756584 -98.022562)
# POINT (16.890991 -97.679463)
# POINT (17.052537 -97.929615)
# POLYGON ((-96.54603488 16.50521793, -96.54631249 16.49860087, -96.54627762 16.4986703, -96.54629103 16.49871917, -96.54635272 16.49873974, -96.546401 16.49876546, -96.54642514 16.49871402, -96.54644928 16.49864973, -96.54645733 16.49861115, -96.54645733 16.49858286, -96.54644391 16.498552, -96.54637418 16.49854172, -96.54633126 16.49855972, -96.54631517 16.49860344, -96.54603488 16.50521793))
# POINT (16.428018 -96.694597)
# POINT (17.338643 -96.96541)
# POINT (16.844038 -97.607389)
# POINT (17.326112 -96.96188)
# POINT (16.920666 -96.429548)
# POINT (16.428641 -96.692462)
# POINT (16.837792 -97.607178)
# POINT (17.330392 -96.962512)
# POINT (16.445857 -96.690667)
# POINT (16.832909 -97.605136)
# POINT (16.830867 -97.602997)
# POINT (16.05638 -96.402045)
# POINT (17.353405 -96.950223)
# POINT (16.434062 -96.704151)
# POINT (16.874918 -96.662641)
# POINT (16.08798 -96.390403)
# POINT (17.34538 -96.948493)
# POINT (16.617526 -96.806846)
# POINT (16.090353 -96.408741)
# POINT (16.876296 -96.662329)
# POINT (17.353678 -96.950396)
# POINT (16.645573 -96.799221)
# POINT (16.435813 -96.697176)
# POINT (16.082021 -96.422479)
# POINT (16.88271 -96.665614)
# POINT (16.627253 -96.803255)
# POINT (16.708429 -97.023132)
# POINT (17.182714 -96.802222)
# POINT (16.620425 -96.807075)
# POINT (16.832326 -97.608928)
# POINT (16.43407 -96.708703)
# POINT (16.879371 -96.659297)
# POINT (16.831585 -97.608792)
# POINT (17.35029 -96.959905)
# POINT (16.652317 -96.813082)
# POINT (16.71914 -97.021751)
# POINT (16.826392 -97.602454)
# POINT (16.619029 -96.793543)
# POINT (16.422191 -96.685987)
# POINT (16.597902 -96.810472)
# POINT (16.420296 -96.702756)
# POINT (16.640152 -96.01838)
# POINT (17.332551 -98.17536)
# POINT (17.182361 -96.801531)
# POINT (16.601212 -96.81604)
# POINT (16.43792 -96.706503)
# POINT (16.826399 -97.603264)
# POINT (16.606698 -96.804788)
# POINT (16.091276 -96.406526)
# POINT (18.173876 -96.689755)
# POINT (16.629454 -96.792079)
# POINT (17.182964 -96.806494)
# POINT (17.23361 -96.84411)
# POINT (16.079492 -96.416903)
# POINT (16.565992 -96.806242)
# POINT (17.22688 -96.84041)
# POINT (16.442155 -96.70517)
# POINT (15.993437 -96.396283)
# POINT (16.601638 -96.798995)
# POINT (17.21777 -96.86012)
# POINT (16.967124 -96.071078)
# POINT (16.438053 -96.706452)
# POINT (16.607642 -96.959325)
# POINT (17.23161 -96.83504)
# POINT (16.640962 -96.803344)
# POINT (16.420773 -96.700901)
# POINT (17.22553 -96.84192)
# POINT (16.59855 -96.798689)
# POINT (17.23137 -96.83174)
# POINT (17.22342 -96.8379)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 pts, pols=to_geopandas_df(octubre_corte,'oct_30_')
#
# Cell In[28], line 30, in to_geopandas_df(df, origin_file)
#      27 sitiosbd_depurate['n_vertices'] = sitiosbd_depurate['info_geo'].apply(lambda x:len(x))
#      28 # sitiosbd_depurate.to_csv(f'{PATH}n_vertices.csv')
#      29 # sitiosbd_depurate['type_geometry'] = sitiosbd_depurate['info_geo'].apply(arreglo)
# ---> 30 sitiosbd_depurate['type_geometry'] = sitiosbd_depurate['info_geo'].apply(geometry_apply)
#      31 sitiosbd_depurate=sitiosbd_depurate[sitiosbd_depurate['type_geometry'].notna()]
#      32 desechados_2=sitiosbd_depurate[sitiosbd_depurate['type_geometry'].isnull()]
#
# File ~/sefader/venv/lib/python3.10/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~/sefader/venv/lib/python3.10/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/sefader/venv/lib/python3.10/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/sefader/venv/lib/python3.10/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/sefader/venv/lib/python3.10/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[26], line 16, in geometry_apply(x)
#      11 n = x
#      12 if len(n) == 2:
#      13     # orden=arreglo(n)
#      14     # p=sorted(n)
#      15     # print(p)
# ---> 16     geometry = Point(n)
#      17 elif len(n) >5 and len(n) %2 == 0: #Nueva validación
#      18     listado = to_matrix(n)
#
# File ~/sefader/venv/lib/python3.10/site-packages/shapely/geometry/point.py:77, in Point.__new__(self, *args)
#      73     raise ValueError(
#      74         f"Point() takes only scalar or 1-size vector arguments, got {args}"
#      75     )
#      76 if not np.issubdtype(coords.dtype, np.number):
# ---> 77     coords = [float(c) for c in coords]
#      78 geom = shapely.points(coords)
#      79 if not isinstance(geom, Point):
#
# File ~/sefader/venv/lib/python3.10/site-packages/shapely/geometry/point.py:77, in <listcomp>(.0)
#      73     raise ValueError(
#      74         f"Point() takes only scalar or 1-size vector arguments, got {args}"
#      75     )
#      76 if not np.issubdtype(coords.dtype, np.number):
# ---> 77     coords = [float(c) for c in coords]
#      78 geom = shapely.points(coords)
#      79 if not isinstance(geom, Point):
#
# ValueError: could not convert string to float: '16°88´05.47´´'

# %%
pts.shape

# %%
pols.shape

# %% [markdown]
# Carga de layers

# %%
# mun_oax = gpd.GeoDataFrame(gpd.read_file('../data/regiones_mun_oax.geojson',geometry='geometry',crs="EPSG:4326"))
reg_oax = gpd.GeoDataFrame(gpd.read_file('../data/regiones_oax.geojson',geometry='geometry',crs="EPSG:4326"))

# %%
ds = gpd.sjoin(pols,reg_oax, how="inner", predicate='within')

# %%
ds.shape

# %%
pts.info()

# %%
# Función para intercambiar el orden de latitud y longitud en cada Point
def swap_lat_lon(point):
    return Point(point.y, point.x)

# Aplica la función a cada fila de la columna 'geometry' para corregir el orden

# %%
pts['type_geometry'] = pts['type_geometry'].apply(swap_lat_lon)

# %%
ds2 = gpd.sjoin(pts,reg_oax, how="inner", predicate='within')

# %%
ds2.shape

# %%
# ds2.explore()

# %%
ds2.shape

# %%
# pts

# %%
# ds2

# %%
ds.info()

# %%
ds2.columns

# %%
ds2['Region'].unique()

# %% [markdown]
# ##### Formateo

# %%
ds['Region'].replace({'Valles centrales':'Valles Centrales'},inplace=True)

# %%
ds['Region'].unique()

# %%
ds2['Region'].replace({'Valles centrales':'Valles Centrales'},inplace=True)

# %%
ds2['Region'].unique()

# %%
ds['Programa'].unique()

# %%
dataframe = pd.concat([ds,ds2],ignore_index=True)

# %%
ds2.to_file('../data/puntos_sept.geojson', driver='GeoJSON')
ds.to_file('../data/poligonos_sept.geojson', driver='GeoJSON')

# %%
dataframe.to_csv('../data/corte_clean_sept.csv')

# %%
dataframe['ID.del.productor'].nunique()

# %%
dataframe['index_right'].head(10)

# %% [markdown]
# ##### Carga datos Aux

# %%
usuarios.head(2)

# %% [markdown]
# #### KPI - Sumarizacion

# %%
# Municipios por región
ds.groupby('Region')['Municipio.areas'].nunique()

# %%
# por región
ds2.groupby('Region')['Municipio.areas'].nunique()

# %%
#posible salida para consumo
pd.DataFrame(ds2.groupby('Region')['Municipio.areas'].nunique()).reset_index()

# %%
# numero de farmers por región
pd.DataFrame(
(ds
 .assign(farmers_unicos = ds['ID.del.productor'] + ds['Nombre.Productor'] + ds['CURP'])
 .groupby('Region')['farmers_unicos'].nunique()
#  .farmers_unicos.nunique()
    # farmers = union_fields.nunique()
)).reset_index()

# %%
#superficie por región
#Posible salida 2
dict(ds.groupby('Region')['Superficie.sembrada'].sum())

# %%
#parcelas por región
dict(ds.groupby('Region')['type_geometry'].nunique())

# %%
#bitacoras por región
dict(ds.groupby('Region')['ID.de.bitacora'].nunique())

# %% [markdown]
# Por tipo de parcela

# %%
ds.groupby('Tipo.de.bitacora')['Superficie.sembrada'].sum().reset_index()

# %%
ds['Tipo.de.bitacora'].replace({'AE':'Área de extensión',
                                'AI':'Área de impacto',
                                'AI simplificada':'Área de impacto',
                                'MODULO':'Módulo'},inplace=True)

# %%
ds.groupby('Tipo.de.bitacora')['Superficie.sembrada'].sum().reset_index()

# %% [markdown]
# Por ciclo Productivo

# %%
dict(ds.groupby('Anio.Bitacora')['Superficie.sembrada'].sum())
#reemplazar guines bajos por espacios

# %% [markdown]
# Por regimén hidríco

# %%
ds.groupby('Regimen.hidrico')['Superficie.sembrada'].sum().reset_index()

# %%
ds.groupby('Regimen.hidrico')['Tipo.de.bitacora'].count().reset_index()

# %% [markdown]
# ##### test section

# %%
# catalogo de desplegables

# %%
list(ds['Anio.Bitacora'].unique())

# %%
list(ds['Region'].unique())

# %%
cat_reg=list(ds['Regimen.hidrico'].unique())

# %%
cat_reg.insert(0,'TODOS')

# %%
cat_reg

# %%
cols = ['Anio.Bitacora','Regimen.hidrico','Region']
options = [['OI_2023_2024', 'PV_2024'],'RIEGO',[ 'Istmo','Mixteca','Costa']]

# %%
list(dict(zip(cols, options)).items())

# %%
def subset(dataset:str, columns_list:list,conditions_list:list) -> list:
    main_diccionary = dict(zip(columns_list,conditions_list))
    ops = [(dataset[llave]==val) for llave,val in list(main_diccionary.items())]
    
    print(ops)
    # return dataset

# %%
subset('name',cols, options)

# %%
listas = pd.read_csv('../data/Listas.csv')

# %%
listas = listas.iloc[:,0:3]

# %%
listas.head(2)

# %%
listas.Lista.unique()

# %%
listado_mun = listas[listas.Lista=='Municipios_mx_list'].reset_index(drop=True)

# %%
listado_mun = listado_mun.iloc[1:,:]

# %%
listado_mun.head(10)

# %%
mun_oax = gpd.GeoDataFrame(gpd.read_file('../data/regiones_oax.geojson',geometry='geometry'))

# %%
mun_oax.info()

# %%
mun_oax

# %%
file_polygons = '../data/poligonos.geojson'

# %%
poli.geometry.iloc[0]

# %%
poli = gpd.GeoDataFrame(gpd.read_file(file_polygons,geometry='geometry'))

# %%
# poli.crs

# %%
# poli.assign(area= poli.geometry.to_crs(epsg=4326))

# %%
# poli.area.head(2)

# %%
# pd.options.display.float_format = '{:.2f}'.format

# %%
# poli.area /10e4

# %%
puntos = gpd.GeoDataFrame(gpd.read_file('../data/puntos.geojson',geometry= 'geometry'))

# %%
puntos["Tipo.de.bitacora"].nunique()

# %%
puntos.geometry.y
